# %% [markdown]
# <a href="https://colab.research.google.com/github/tlsrudwns111/NVIDIA/blob/yolov8/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. ultralytics 설치
# !pip install ultralytics

# 2. YOLO 모델 불러오기
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # 또는 yolov8s.pt

# 3. 이미지 업로드
from google.colab import files
uploaded = files.upload()

# 4. 파일 이름 얻기
image_path = next(iter(uploaded))

# 5. 감지 수행
results = model(image_path)

# 6. 사람, 백팩, 핸드백 정보 출력
target_labels = ['person', 'backpack', 'handbag']
for result in results:
    boxes = result.boxes
    for box in boxes:
        cls = int(box.cls[0])
        label = model.names[cls]
        if label in target_labels:
            print(f"'{label}' 감지됨! 위치:", box.xyxy[0].tolist())

# 7. 시각화된 결과 보기
results[0].show()
# Out:
# ...
#      <input type="file" id="files-b1552afc-880e-4eaa-bb20-0b24d388e771" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1552afc-880e-4eaa-bb20-0b24d388e771">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
